# %% [markdown]
# # YouTube Video First Minute Extraction Pipeline
#
# ## Overview
# This Jupyter notebook contains functionality for extracting the first minute of audio from YouTube videos. The pipeline processes MP4 files and converts them to MP3 format, keeping track of processed files to avoid duplicate work.
#
# ### Key Features
# - Extracts first 60 seconds of audio from MP4 videos
# - Converts video to MP3 format using FFmpeg
# - Maintains processing logs to track completed files
# - Includes utilities for:
#   - Finding MP4 files in directories
#   - Processing file management
#   - Log concatenation and analysis
#
# ### Prerequisites

# %%
import pandas as pd
import os
import ffmpeg # ffmpeg-python
import subprocess

# %% [markdown]
# ### Usage
# The pipeline processes MP4 files from a specified input directory, extracts the first minute of audio, and saves them as MP3 files in an output directory. It maintains a log of processed files to enable resumption of interrupted processing.
#
# ### Configuration
# - `INPUT_FOLDER`: Source directory containing MP4 files
# - `OUTPUT_FOLDER`: Destination directory for processed MP3 files
# - `LOG_FILE`: File tracking processed videos
#
# ### Additional Tools
# Includes utilities for:
# - Log file analysis and concatenation
# - File extension detection
# - Video processing status verification

# %%
def find_mp4_files(folder_path):
    """Returns a list of .mp4 file names without the extension."""
    mp4_files = [
        os.path.splitext(file)[0] for file in os.listdir(folder_path) if file.lower().endswith(".mp4")
    ]
    return mp4_files

folder_path = '../../YouTube_Downloader/Downloads'
mp4_files = find_mp4_files(folder_path)

# %%
INPUT_FOLDER = '../../YouTube_Downloader/Downloads'
OUTPUT_FOLDER = 'First_minute_videos'  
LOG_FILE = "processed_files.log"

def find_mp4_files(folder_path):
    """Returns a list of .mp4 file names without the extension."""
    mp4_files = [
        os.path.splitext(file)[0] for file in os.listdir(folder_path) if file.lower().endswith(".mp4")
    ]
    return mp4_files

def load_processed_files():
    """Reads the log file and returns a set of processed filenames."""
    if not os.path.exists(LOG_FILE):
        return set()
    
    with open(LOG_FILE, "r") as f:
        return set(line.strip() for line in f.readlines())

def save_processed_file(filename):
    """Appends a successfully processed filename to the log file."""
    with open(LOG_FILE, "a") as f:
        f.write(filename + "\n")

def extract_audio(filename):
    """Extracts the first 60 seconds of audio from the given .mp4 file."""
    input_path = os.path.join(INPUT_FOLDER, filename + ".mp4")
    output_path = os.path.join(OUTPUT_FOLDER, filename + ".mp3")

    if not os.path.exists(input_path):
        print(f"File not found: {input_path}")
        return False

    command = [
        "ffmpeg",
        "-i", input_path,  # Input file
        "-t", "60",  # Duration: 60 seconds
        "-q:a", "2",  # Quality setting for MP3
        "-vn",  # No video
        output_path  # Output file
    ]

    try:
        subprocess.run(command, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        print(f"Successfully processed: {filename}")
        return True
    except subprocess.CalledProcessError:
        print(f"Failed to process: {filename}")
        return False

def process_files(file_list):
    """Processes each file, extracting the first 60 seconds of audio, skipping processed ones."""
    processed_files = load_processed_files()

    for filename in file_list:
        if filename in processed_files:
            print(f"Skipping {filename}, already processed.")
            continue

        if extract_audio(filename):
            save_processed_file(filename)

# %%
mp4_files = find_mp4_files(INPUT_FOLDER)
process_files(mp4_files)
# Out:
# Skipping hZN9-pn7cPM, already processed.
# Skipping rvCd2GviguU, already processed.
# Skipping XCvQFgUx7Xg, already processed.
# Skipping qgtiRkFDUrI, already processed.
# Skipping yRPLrDnkZ7I, already processed.
# Skipping r1VacSU8kFA, already processed.
# Skipping 6oeQfEnMHIU, already processed.
# Skipping 2NNAccP5Vvg, already processed.
# Skipping EjLXRGpZKv8, already processed.
# Skipping p1dSJtBbzhg, already processed.
# Skipping ZwxJk-noC4I, already processed.
# Skipping xw490NjBY0Y, already processed.
# Skipping LaVd7qRxqDk, already processed.
# Skipping sBCCjhK2CAg, already processed.
# Skipping 78I9zOUPuBI, already processed.
# Skipping _avT-3l0fL0, already processed.
# Skipping CvwAPi8ishw, already processed.
# Skipping hQ3FnfqUuwA, already processed.
# Skipping 7968d4lGYY8, already processed.
# Skipping afTv-DVZBTo, already processed.
# Successfully processed: uc4yoIwGqOc
# Successfully processed: Ini186efqmc
# Successfully processed: rqANzQL2Ynw
# Successfully processed: 9kvkaFKoYlI
# Successfully processed: YQQokcoOzeY
# Successfully processed: F4GCCFlex9Q
# Successfully processed: ZrFQSGD8djU
# Successfully processed: PgRafRp-P-o
# Successfully processed: N55FU0LYlt4
# Successfully processed: WXmbRREbXk0
# Successfully processed: 9c2NqlUWZfo
# Successfully processed: L9wyJOHsY10
# Successfully processed: 2BApBnR2WG8
# Successfully processed: ZKYoJUFo2kw
# Successfully processed: 6jJkdRaa04g
# Successfully processed: IiHFnmI8pxg
# Successfully processed: F33xF-Ijhak
# Successfully processed: 9AlKQm24z3w
# Successfully processed: SukzG9R-56Y
# Successfully processed: 1QYryicPE_M
# Successfully processed: 0OIX2U6KD0g
# Successfully processed: UMr4WqQ5Jc4
# Successfully processed: pHNCzBXtZ6I
# Successfully processed: kqGsh5sloNE
# Successfully processed: VDF0WZTIns0
# Successfully processed: HI2EfIV6jAs
# Successfully processed: dv7BDkQmvhA
# Successfully processed: 3OtEpbG69lA
# Successfully processed: 9sGaS9flDh4
# Successfully processed: Mt3eexuKelg
# Successfully processed: rn_YIaIbrDI
# Successfully processed: 16y1AkoZkmQ
# Successfully processed: R1dILTUMJQI
# Successfully processed: eSXDa_CJrds
# Successfully processed: Q1CLFgOaUFE
# Successfully processed: K_RNpj4JZbA
# Successfully processed: Ipo5zzFqaGA
# Successfully processed: hQAMsCm6jkE
# Successfully processed: -ryWxUYVeko
# Successfully processed: _XL9q6GY3W0
# Successfully processed: 0z5G7OXG6MY
# Successfully processed: x4yn1ZYpbQQ
# Successfully processed: PV32KQMaQew
# Successfully processed: 9nXH8Stm3Tg
# Successfully processed: dBkqpcb3Waw
# Successfully processed: mVMJ1O-4RfM
# Successfully processed: NiXtswuE1MI
# Successfully processed: 8QybC0QiUGU
# Successfully processed: ipQ1c6jTjIc
# Successfully processed: auFHTIYm2WA
# Successfully processed: uOz_NilcTSg
# Successfully processed: -3b1P5eLWZM
# Successfully processed: gX-JheaK8GA
# Successfully processed: mlMWBccgirg
# Successfully processed: 6JQm5aSjX6g
# Successfully processed: gyUwbEzmN5k
# Successfully processed: hlaoi7I1cxM
# Successfully processed: PEZL4dn5S50
# Successfully processed: Tl4s7oFKwCM
# Successfully processed: GPef9H7uUjE
# Successfully processed: _UsO73sxPzQ
# Successfully processed: NxrpBNm0_V8
# Successfully processed: NNw_yueOiBk
# Successfully processed: 5EYrzSX934k
# Successfully processed: qJATcMCuM5s
# Successfully processed: ATX6j4pKP-E
# Successfully processed: HlAJxGhHjCg
# Successfully processed: NFVLCugnsYE
# Successfully processed: 8qFFubIiX8M
# Successfully processed: o8f-Pq9YDIc
# Successfully processed: Omh7IFxs1kQ
# Successfully processed: lkXqiB0EJys
# Successfully processed: nhLDDgTmqI0
# Successfully processed: D_orL8BFFqo
# Successfully processed: 6bi4_sAi0gE
# Successfully processed: wRCoB3Gauc8
# Successfully processed: mf1HDrZyFpQ
# Successfully processed: eiqsjlGO8Ao
# Successfully processed: wDc1gbQIkBQ
# Successfully processed: 28k53NsAcVg
# Successfully processed: 2vypAlmusxM
# Successfully processed: -1jPUB7gRyg
# Successfully processed: C2-jmjdMPwM
# Successfully processed: KrjL_TSOFrI
# Successfully processed: iTNCnrHI9Y8
# Successfully processed: vT8e66l1bCg
# Successfully processed: TMyTF7cFjcg
# Successfully processed: H8Xr-YPbGfU
# Successfully processed: 1Jvx_umysik
# Successfully processed: kGSQmWcAyho
# Successfully processed: Ixrje2rXLMA
# Successfully processed: u6s0d-HFwXY
# Successfully processed: -ZaXRRDEGQA
# Successfully processed: GIy9-bBm6LE
# Successfully processed: x6WYz7257m4
# Successfully processed: EE6YRQABzEI
# Successfully processed: LhsjPRtFWxQ
# Successfully processed: fOSir7N3VPk
# Successfully processed: 8_E7Zv-e6Ns
# Successfully processed: ZO6NC3Vh0KE
# Successfully processed: a4cvfDWZC7U
# Successfully processed: xb4Yk3lHRL0
# Successfully processed: BcPzEEyfBIk
# Successfully processed: IA3fUSJ0ZOE
# Successfully processed: FXhdTKWMj_M
# Successfully processed: TNC7xExD6Wo
# Successfully processed: H-4GM9LxJP8
# Successfully processed: 73pswBZxhgc
# Successfully processed: tRD9l5yiNzM
# Successfully processed: p-zdPKRm-i4
# Successfully processed: Taoh0_08u3s
# Successfully processed: 0aO87sdBet0
# Successfully processed: 99VZjqcL6oc
# Successfully processed: 9wbGO0fXnp8
# Successfully processed: GJgTtU9TCyQ
# Successfully processed: J0UThpYrv9c
# Successfully processed: rQCkWaDLyeg
# Successfully processed: 8xiXLR5rNIo
# Successfully processed: TcYE1-By46k
# Successfully processed: 6Sul0TMJWAQ
# Successfully processed: Xt09iNPBCiQ
# Successfully processed: CDLADwjgXWY
# Successfully processed: Ugx06TlVyw4
# Successfully processed: Yz8U-ZetXRc
# Successfully processed: awlmi3L7xRM
# Successfully processed: DPt7aMrt5s4
# Successfully processed: rHa-bqCTQUw
# Successfully processed: kiisRiUiZo4
# Successfully processed: y_zeJbgFsyc
# Successfully processed: 2A7RfJgAJaE
# Successfully processed: XRcn7oMiV3w
# Successfully processed: vowp_GkNQ0c
# Successfully processed: I5Hh2s7iahI
# Successfully processed: frDHdSJd2ig
# Successfully processed: AIEpPaEp4WI
# Successfully processed: l0afZRKskLU
# Successfully processed: ziPvKbfp_EA
# Successfully processed: 7W0fsSC0AnM
# Successfully processed: kX00KF5oMXQ
# Successfully processed: YQuJQtcw1kA
# Successfully processed: WQVD_gQ_Ko4
# Successfully processed: -R_u8mHKjtA
# Successfully processed: nAxIsh-KsSw
# Successfully processed: 4S1Mgm3eVmY
# Successfully processed: gEhKPo42uS0
# Successfully processed: lXw4652aUtg
# Successfully processed: 8Fnw9Zem_F8
# Successfully processed: I8WIwY7XHlM
# Successfully processed: WIoMP0Q7pIw
# Successfully processed: c7SpyNDKx1Y
# Successfully processed: W-dxkkp_Wv4
# Successfully processed: qfYKxMBpkM8
# Successfully processed: s-RFqYTh9jw
# Successfully processed: oncBOW_sef8
# Successfully processed: HlyoanWE4nI

# %% [markdown]
# ### In other news:

# %%
def concatenate_logs(log_path):
    dataframes = []
    
    # Iterate over all files in the folder
    for filename in os.listdir(log_path):
        # Check if the file is a CSV
        if filename.endswith(".csv"):
            file_path = os.path.join(log_path, filename)
            
            # Read CSV file into a DataFrame and append it to the list
            df = pd.read_csv(file_path, dtype={'Participant ID': str, 'video_id': str})
            if 'log' in df.columns:
                df = df.drop(columns=['log'])
            dataframes.append(df)
    
    # Concatenate all DataFrames in the list
    if dataframes:  # Check if there are any dataframes to concatenate
        concatenated_df = pd.concat(dataframes, ignore_index=True)
    else:
        concatenated_df = pd.DataFrame()  # Return an empty DataFrame if no CSV files found
    
    return concatenated_df
log_df = concatenate_logs('../../YouTube_Downloader/Log_Entries')

# %%
def find_mp4_files(folder_path):
    """Returns a list of .mp4 file names without the extension."""
    mp4_files = [
        os.path.splitext(file)[0] for file in os.listdir(folder_path) if file.lower().endswith(".mp4")
    ]
    return mp4_files

folder_path = '../../YouTube_Downloader/Downloads'
mp4_files = find_mp4_files(folder_path)

# %%
def concatenate_logs(log_path):
    dataframes = []
    
    # Iterate over all files in the folder
    for filename in os.listdir(log_path):
        # Check if the file is a CSV
        if filename.endswith(".csv"):
            file_path = os.path.join(log_path, filename)
            
            # Read CSV file into a DataFrame and append it to the list
            df = pd.read_csv(file_path, dtype={'Participant ID': str, 'video_id': str})
            if 'log' in df.columns:
                df = df.drop(columns=['log'])
            dataframes.append(df)
    
    # Concatenate all DataFrames in the list
    if dataframes:  # Check if there are any dataframes to concatenate
        concatenated_df = pd.concat(dataframes, ignore_index=True)
    else:
        concatenated_df = pd.DataFrame()  # Return an empty DataFrame if no CSV files found
    
    return concatenated_df
log_df = concatenate_logs('../../YouTube_Downloader/Log_Entries')

# %%
df = log_df[log_df['status']=='successful']

# %%
set(df['video_id']) - set(mp4_files)
# Out:
# {'-m7NcPgFQv0',
#  '1cYs-eynpQc',
#  '1yAQhRP-UJ8',
#  '3KI2_cpR9Ek',
#  '3PBecE4J5ak',
#  '6aO3_nd0jPM',
#  '7vuE4TP7Ta8',
#  '84QsAF6FYg0',
#  '8zEPlkPAlNQ',
#  'B3fDZz3IS2Q',
#  'B6cLl_hHm7Y',
#  'CH4dkLvZkKc',
#  'DUID0Y2VwPw',
#  'G87fDW89hjI',
#  'GUWHTIZbmkw',
#  'Gy1M2KpBWII',
#  'HyAGMjbIFqY',
#  'ITJ3AF3TK5M',
#  'ItkhXq1N5gg',
#  'JZRpVSn_Z4A',
#  'KMWZE6ekIIc',
#  'LwiG0j7PMG8',
#  'MBg2sxYQLYs',
#  'MDVyM3w3RwE',
#  'OR23wIADpsM',
#  'QZQ90uH-NKo',
#  'Ts8Bjkpsim8',
#  'Vue2J0qbN20',
#  'W90w6xm6LJU',
#  '_HUTXfdKoe8',
#  'bCR2dUrxPk4',
#  'cm0i2ewsi3Y',
#  'dLF1qgYSQ38',
#  'dZtjtiiT5SI',
#  'dlJNqEaSjcw',
#  'hcwrfBfwUhc',
#  'iMfMGMu7KiI',
#  'jXYOylTeFqo',
#  'k-6P1H2rLmY',
#  'l8h3AFKrADo',
#  'lVlFwwzi7Ok',
#  'pY9H6DxhN8o',
#  'rMl4CmbmtGQ',
#  'rfYfuAOKTxA',
#  'rtT6odWzKbQ',
#  'u7PAK5B8JC4',
#  'v0WgqPU25oI',
#  'wVZ8HBxb9Nk',
#  'x_21VQxe_1E',
#  'yJbHoajwhQM',
#  'yJvR16wRLFs',
#  'ydszZrNW_Iw',
#  'zt5J8zV7f5s'}

# %%
def find_file_extension(ID, folder_path='../../YouTube_Downloader/Downloads/'):
    """Searches for a file in the folder by name (ignoring extension) and returns its extension."""
    for file in os.listdir(folder_path):
        name, ext = os.path.splitext(file)
        if name == ID:
            return ext 
            
find_file_extension('rMl4CmbmtGQ')

# %%
log_df[log_df['video_id']=='rMl4CmbmtGQ']
# Out:
#      Participant ID     video_id      status         server_reply  size_MB  \
# 7700          23690  rMl4CmbmtGQ  successful  Download successful      NaN
#
#                       start_time                    end_time  \
# 7700  2025-02-11 17:52:01.804688  2025-02-11 17:52:06.205357
#
#       download_time_minutes  download_speed_KBs format vcodec acodec
# 7700                   0.07                 NaN    NaN    NaN    NaN

# %% [markdown]
# ### 53 vidoes are marked as downloaded but do not seem to be downloaded...
